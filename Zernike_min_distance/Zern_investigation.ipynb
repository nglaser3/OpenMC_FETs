# %%
'''
Zernike.py imports already imports the following:
from math import *
import scipy
import matplotlib.pyplot as plt
import numpy as np
'''
from Zernike import *

# %%
_n1,_n2 = (7,19)
_m1,_m2 = (-5,-5)
_ri,_ro = (0,1)
z1,z2 = get_two(_n1,_n2,_m1,_m2,rmin=_ri,rmax=_ro)
check_ortho(z1,z2,r_bounds=(_ri,_ro))
# Out:
# (1.025965280081875e-12, 1.0990744977318334e-08)

# %%
a = zernike(6,2)
a.get_c_p()
a.get_radial()
a.get_function()

b = zernike(6,4)
b.get_c_p()
b.get_radial()
b.get_function()

a.plot_rad(show=False)
b.plot_rad()

a_f = a.func
b_f = b.func

check_ortho(a_f,b_f,r_bounds=(0,1))
# Out:
# (-1.3539158930323496e-17, 3.4232599394057317e-15)

# %%
a = zernike(2,2)
a.get_c_p()
a.get_function()

# %%
a.func(0.7,3)
# Out:
# 1.152444361552875
