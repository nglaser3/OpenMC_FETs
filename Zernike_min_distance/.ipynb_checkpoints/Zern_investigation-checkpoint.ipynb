# %%
'''
Zernike.py imports already imports the following:
from math import *
import scipy
import matplotlib.pyplot as plt
import numpy as np
'''
from Zernike import *

# %%
_n1,_n2 = (7,19)
_m1,_m2 = (-7,-5)
_ri,_ro = (0,1)
z1,z2 = get_two(_n1,_n2,_m1,_m2,rmin=_ri,rmax=_ro)
check_ortho(z1,z2,r_bounds=(_ri,_ro))
# Out:
# (6.148416392559679e-13, 1.1962443424717861e-08)

# %%
a = zernike(4,2,ri=.5)
a.get_c_p()
a.get_radial()
a.get_function()

b = zernike(4,2)
b.get_c_p()
b.get_radial()
b.get_function()

a.plot_rad(show=False)
b.plot_rad()

a_f = a.func
b_f = b.func

check_ortho(a_f,b_f,r_bounds=(.5,1))
# Out:
# (0.5057043650793651, 3.711789695048928e-10)
