# %%
from Zernike import *

# %%
z1,z2 = get_two(4,6,2,0)
check_ortho(z1,z2,r_bounds=(.1,1))
# Out:
# (-3.8434915679108936e-18, 8.413605226818535e-13)

# %%
z = zernike(n=1,m=-1)
z.get_c_p()
z.get_function()
z.plot()

# %%
# Out:
# [7, 5, 3, 1]
